# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabi-galv/Data-science-I/blob/main/Entrega1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.Configuración del entorno

# %%
# Importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #2.Carga del dataset

# %%
df = pd.read_csv( ' https://raw.githubusercontent.com/Gabi-galv/Data-science-I/refs/heads/main/SAT-SS-BU_2017-2023.csv ', sep=";")

# %%
# Exploración de los datos

print('Primeras 5 filas del DataSet')
df.head()
# Out:
# Primeras 5 filas del DataSet
#    id_hecho           tipo_persona_id federal  provincia_id provincia_nombre  \
# 0      8529  Suicida idRegistro 20712      No            42         La Pampa
# 1      8530  Suicida idRegistro 20713      No            42         La Pampa
# 2      8569  Suicida idRegistro 20752      No            78       Santa Cruz
# 3      8705  Suicida idRegistro 20894      No            58          Neuquén
# 4      8706  Suicida idRegistro 20895      No            58          Neuquén
#
#    departamento_id   departamento_nombre localidad_id localidad_nombre  anio  \
# 0            42002  Norte (General Pico)       105030     General Pico  2017
# 1            42003    Sur (General Acha)        70030        Guatraché  2017
# 2            78021             Güer Aike           60  28 de Noviembre  2017
# 3            58035           Confluencia           70          Neuquén  2017
# 4            58035           Confluencia          100         Plottier  2017
#
#    ...  modalidad_ampliado modalidad_otro motivo_origen_registro  \
# 0  ...        Ahorcamiento            NaN  Intervención policial
# 1  ...       Arma de fuego            NaN  Intervención policial
# 2  ...        Ahorcamiento            NaN    Denuncia particular
# 3  ...       Arma de fuego            NaN  Intervención policial
# 4  ...        Ahorcamiento            NaN  Intervención policial
#
#   motivo_origen_registro_otro suicida_sexo suicida_tr_edad  \
# 0                         NaN    Masculino           20-24
# 1                         NaN    Masculino           55-59
# 2                         NaN    Masculino           15-19
# 3                         NaN    Masculino           20-24
# 4                         NaN    Masculino           20-24
#
#   suicida_18_años_o_mas      suicida_clase suicida_clase_otro  \
# 0                    Si  Sin determinación                NaN
# 1                    Si  Sin determinación                NaN
# 2                    No  Sin determinación                NaN
# 3                    Si  Sin determinación                NaN
# 4                    Si  Sin determinación                NaN
#
#   suicida_identidad_genero
# 0           Sin determinar
# 1           Sin determinar
# 2           Sin determinar
# 3           Sin determinar
# 4           Sin determinar
#
# [5 rows x 27 columns]

# %%
#Info del dataframe

print('Información del DataSet')
df.info()
# Out:
# Información del DataSet
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25920 entries, 0 to 25919
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_hecho                     25920 non-null  int64
#  1   tipo_persona_id              25920 non-null  object
#  2   federal                      25920 non-null  object
#  3   provincia_id                 25920 non-null  int64
#  4   provincia_nombre             25920 non-null  object
#  5   departamento_id              25920 non-null  int64
#  6   departamento_nombre          25920 non-null  object
#  7   localidad_id                 25920 non-null  object
#  8   localidad_nombre             25920 non-null  object
#  9   anio                         25920 non-null  int64
#  10  mes                          25920 non-null  int64
#  11  fecha_hecho                  25920 non-null  object
#  12  hora_hecho                   25920 non-null  object
#  13  tipo_lugar                   25920 non-null  object
#  14  tipo_lugar_ampliado          25918 non-null  object
#  15  tipo_lugar_otro              1471 non-null   object
#  16  modalidad                    25920 non-null  object
#  17  modalidad_ampliado           25920 non-null  object
#  18  modalidad_otro               271 non-null    object
#  19  motivo_origen_registro       25920 non-null  object
#  20  motivo_origen_registro_otro  17 non-null     object
#  21  suicida_sexo                 25920 non-null  object
#  22  suicida_tr_edad              25920 non-null  object
#  23  suicida_18_años_o_mas        25920 non-null  object
#  24  suicida_clase                25920 non-null  object
#  25  suicida_clase_otro           12 non-null     object
#  26  suicida_identidad_genero     25920 non-null  object
# dtypes: int64(5), object(22)
# memory usage: 5.3+ MB

# %%
#cambio tipo de dato de "fecha_hecho" y "hora_hecho"
df['fecha_hecho'] = pd.to_datetime(df['fecha_hecho'], format='%d/%m/%Y', errors='coerce')
df['hora_hecho'] = pd.to_datetime(df['hora_hecho'], format='%H:%M', errors='coerce').dt.time
